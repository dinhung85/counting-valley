# %%
# s = 'UDDDUDUU'
s = 'DDUUDDDUDUUDUDDDUUDDUDDDUDDDUDUUDDUUDDDUDDDUDDDUUUDUDDDUDUDUDUUDDUDUDUDUDUUUUDDUDDUUDUUDUUDUUUUUUUUU'
# s = '...'
n = len(s)

ud = {"U":1,"D":-1}

# Complete the countingValleys function below.
def countingValleys(n, s):
	s_list = int(s)
	print(s_list)
	n_list =[]
	m = 0
	sl=0
	sea_level = [0]
	for i in s_list:
		n_list.append(ud[i])
		sl = sl + ud[i]
		sea_level.append(sl)
		sea_level_string = '>'.join(str(e) for e in sea_level)
	df = pd.DataFrame({'col':sea_level})
	print (df)
	m = sea_level_string.count('-1>0')
	print(sea_level_string)
	sea_level_string = sea_level_string.replace('-1>0','\_/')
	print(s)
	print(sea_level_string, m)
	df.plot()
	return m

countingValleys(n,s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-2cd086703a16> in <module>
#      30         return m
#      31
# ---> 32 countingValleys(n,s)
#
# <ipython-input-57-2cd086703a16> in countingValleys(n, s)
#       9 # Complete the countingValleys function below.
#      10 def countingValleys(n, s):
# ---> 11         s_list = int(s)
#      12         print(s_list)
#      13         n_list =[]
#
# ValueError: invalid literal for int() with base 10: 'DDUUDDDUDUUDUDDDUUDDUDDDUDDDUDUUDDUUDDDUDDDUDDDUUUDUDDDUDUDUDUUDDUDUDUDUDUUUUDDUDDUUDUUDUUDUUUUUUUUU'

# %%
# Out:
#     col
# 0     0
# 1     1
# 2     0
# 3    -1
# 4     0
# 5     1
# 6     2
# 7     1
# 8     0
# 9    -1
# 10    0
# 11    1
# 12    0
# 13   -1
# 14   -2
# 15   -3
# 16   -4
# 17   -3
# 18   -2
# 19   -1
# 20    0
# 21   -1
# 22   -2
# 23   -3
# 24   -4
# 25   -5
# 26   -6
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-fc56fa882bf0> in <module>
#       1 df.plot()
#       2 print (df)
# ----> 3 m = sea_level_string.count('-10')
#       4 print(sea_level_string, m)
#
# NameError: name 'sea_level_string' is not defined
